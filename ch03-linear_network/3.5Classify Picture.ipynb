# %% [markdown]
# # 手写数字识别（图像分类）

# %% [markdown]
# 这里使用不适用比较简单的mnist数据集，而是使用比较复杂的Fashion-MNIST数据集。

# %% [markdown]
# # 读取数据集

# %% [markdown]
# 通过框架的API下载数据集并读取到内存中，该数据集有十个分类，每个类别包括6000张train和1000张test。 \
# 数据集为灰度图，每个像素的取值范围为0-255。每张图片的像素数量为28*28=784，通道数为1。

# %%
import torch
import torchvision
from torch.utils import data
from torchvision import transforms
from d2l import torch as d2l

trans = transforms.ToTensor() # 这里创建了一个Totensor实例对象（可以理解为一个数据转换器），trans是这个实例对象的变量名
# 数据转换操作，将PIL图像转换为Pytorch张量，像素值归一化到0.0-1.0，维度顺序从（高度，宽度，通道）变为（通道， 高度， 宽度）
mnist_train = torchvision.datasets.FashionMNIST(
    root="../data", train=True, transform=trans, download=True)
mnist_test = torchvision.datasets.FashionMNIST(
    root="../data", train=False, transform=trans, download=True)
# Out:
# ...
# 26422272it [00:04, 5482942.94it/s]
# Extracting ../data\FashionMNIST\raw\train-images-idx3-ubyte.gz to ../data\FashionMNIST\raw
#
# ...
# 29696it [00:00, 201141.16it/s]
# Extracting ../data\FashionMNIST\raw\train-labels-idx1-ubyte.gz to ../data\FashionMNIST\raw
#
# ...
# 4422656it [00:01, 3686104.58it/s]
# Extracting ../data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz to ../data\FashionMNIST\raw
#
# ...
# 6144it [00:00, ?it/s]
# Extracting ../data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz to ../data\FashionMNIST\raw

# %%
len(mnist_train),len(mnist_test),mnist_train[0][0].shape
# Out:
# (60000, 10000, torch.Size([1, 28, 28]))

# %% [markdown]
# 在十个类别数字和标签名之间进行转换

# %%
def get_fashion_mnist_labels(labels):  
    """返回Fashion-MNIST数据集的文本标签"""
    text_labels = ['t-shirt', 'trouser', 'pullover', 'dress', 'coat',
                   'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']
    return [text_labels[int(i)] for i in labels]  # 列表推导式
# 列表推导式：[表达式 for 变量 in 可迭代对象]
# 列表推导式的作用：将可迭代对象中的每个元素应用表达式，生成一个新的列表。
